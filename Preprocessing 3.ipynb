# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',150)
pd.set_option('display.max_rows',150)

# %%
df1 = pd.read_csv('hyd_third_rentals_000.csv')
df2 = pd.read_csv('hyd_third_rentals_100.csv')
df3 = pd.read_csv('hyd_third_rentals_200.csv')
df4 = pd.read_csv('hyd_third_rentals_300.csv')
df5 = pd.read_csv('hyd_third_rentals_400.csv')
df6 = pd.read_csv('hyd_third_rentals_414.csv')

# %%
df1.head()
# Out:
#                                                 link   prop_id
# 0  openDetailPage(event, 'https://www.magicbricks...  48930897
# 1  openDetailPage(event, 'https://www.magicbricks...  57083523
# 2  openDetailPage(event, 'https://www.magicbricks...  57071547
# 3  openDetailPage(event, 'https://www.magicbricks...  56793769
# 4  openDetailPage(event, 'https://www.magicbricks...  54630391

# %%
frames1 = [df1, df2]
df_cat1 = pd.concat(frames1)

frames2 = [df_cat1, df3]
df_cat2 = pd.concat(frames2)

frames3 = [df_cat2, df4]
df_cat3 = pd.concat(frames3)

frames4 = [df_cat3, df5]
df_cat4 = pd.concat(frames4)

frames5 = [df_cat4, df6]
df_cat5 = pd.concat(frames5)

# %%
df_cat5.shape
# Out:
# (11152, 2)

# %%
df_cat5.drop_duplicates(subset=['prop_id'],inplace=True)

# %%
df_cat5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9314 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   link     7024 non-null   object
#  1   prop_id  9314 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 218.3+ KB

# %%
df_cat5.shape
# Out:
# (9314, 2)

# %%
df_cat5.reset_index(drop=True, inplace=True)

# %%
df_cat5.shape
# Out:
# (9314, 2)

# %%
df_cat5.loc[0,'link']
# Out:
# "openDetailPage(event, 'https://www.magicbricks.com/propertyDetails/2-BHK-1100-Sq-ft-Residential-House-FOR-Rent-Beeramguda-in-Hyderabad-r1&id=4d423438393330383937?sem=Y&semsrc=CPLADS_1_PDP_Existing_Web&slot=1','48930897',true);"

# %%
a = df_cat5.loc[0,'link']

# %%
len("openDetailPage(event, 'https://www.magicbricks.com/propertyDetails/2-BHK-")
# Out:
# 73

# %%
a[73:77]
# Out:
# '1100'

# %%
df_cat5['link'] = df_cat5['link'].astype(str)

# %%
links_list = df_cat5['link'].tolist()

# %%
df_cat5['area_sqft'] = [x[73:77] for x in links_list]

# %%
df_cat5['area_sqft'] = df_cat5['area_sqft'].str.replace('-','')
df_cat5['area_sqft'] = df_cat5['area_sqft'].str.replace(r'[A-Za-z]+','')
df_cat5['area_sqft'] = df_cat5['area_sqft'].replace(r'^\s*$', np.nan, regex=True)
# Out:
# <ipython-input-103-da7b7920c2e0>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_cat5['area_sqft'] = df_cat5['area_sqft'].str.replace(r'[A-Za-z]+','')

# %%
df_cat5.tail(150)
# Out:
#                                                    link   prop_id area_sqft
# 9164  openDetailPage(event, 'https://www.magicbricks...  56326241       945
# 9165  openDetailPage(event, 'https://www.magicbricks...  54612651      4500
# 9166  openDetailPage(event, 'https://www.magicbricks...  55107671       900
# 9167  openDetailPage(event, 'https://www.magicbricks...  56237551      1100
# 9168  openDetailPage(event, 'https://www.magicbricks...  55329381      1800
# 9169  openDetailPage(event, 'https://www.magicbricks...  56228421      4000
# 9170  openDetailPage(event, 'https://www.magicbricks...  54533403      1800
# 9171  openDetailPage(event, 'https://www.magicbricks...  31353197      1740
# 9172  openDetailPage(event, 'https://www.magicbricks...  36360695      1580
# 9173  openDetailPage(event, 'https://www.magicbricks...  49404415      2180
# 9174  openDetailPage(event, 'https://www.magicbricks...  47511113      1500
# ...

# %%
df_cat5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9314 entries, 0 to 9313
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   link       9314 non-null   object
#  1   prop_id    9314 non-null   int64
#  2   area_sqft  6929 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 218.4+ KB

# %%
df_cat5['area_sqft'] = df_cat5['area_sqft'].astype(float)

# %%
df_cat5.drop(columns=['link'],inplace=True)

# %%
df_cat5.head(150)
# Out:
#       prop_id  area_sqft
# 0    48930897     1100.0
# 1    57083523     2000.0
# 2    57071547     1890.0
# 3    56793769     3800.0
# 4    54630391     1860.0
# 5    55683219     4300.0
# 6    56498743     1835.0
# 7    55715405     2800.0
# 8    53849419     1310.0
# 9    56051149     1400.0
# 10   57031233     1410.0
# 11   53468361     1198.0
# 12   46503971      900.0
# 13   56969627     1000.0
# 14   57033051     1400.0
# 15   56585031     1550.0
# 16   57072355     1840.0
# 17   57080653     1150.0
# 18   57011105      787.0
# 19   57083809        NaN
# 20   57087771     1500.0
# 21   57037109     2160.0
# 22   56988121      900.0
# 23   55884259     1750.0
# 24   57020727     1175.0
# 25   57021743     1853.0
# 26   56995675     1100.0
# 27   57033049      990.0
# 28   57023169     1841.0
# 29   57037373     1040.0
# 30   57030399     1500.0
# 31   57053881     2400.0
# 32   35526399     1250.0
# 33   42849167     1000.0
# 34   56937847     1512.0
# 35   56840561     1945.0
# ...

# %%
df_cat5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9314 entries, 0 to 9313
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   prop_id    9314 non-null   int64
#  1   area_sqft  6929 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 145.7 KB

# %%
df_cat5.to_csv('concat_third.csv',index=False)
